# %% [markdown]
# # MCQ — Sales Forecasting Datathon 2026
# Analysis notebook for the multiple-choice / theory component.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

DATA_DIR = '../data/'

# %% [markdown]
# ## Q1 — (paste question here)

# %%
# Working / calculations for Q1

# %% [markdown]
# ## Q2

# %%
# Working for Q2
